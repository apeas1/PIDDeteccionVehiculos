# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.9 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !git config --global user.name "usuario"  #Aqui se modifica para añadir tu usuario de github
# !git config --global user.email "correo"  #Aqui se modifica para añadir tu correo asociado a github

# %%
# !git clone https://token@github.com/apeas1/PIDDeteccionVehiculos.git
# Out:
# Cloning into 'PIDDeteccionVehiculos'...
# remote: Enumerating objects: 5199, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 5199 (delta 19), reused 11 (delta 4), pack-reused 5141 (from 2)
# Receiving objects: 100% (5199/5199), 529.93 MiB | 36.54 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Updating files: 100% (7577/7577), done.

# %%
cd PIDDeteccionVehiculos/Entrega_Final
# Out:
# /content/PIDDeteccionVehiculos/Entrega_Final

# %%
model = YOLO('Modelo_Final/best.pt')

# %%
results = model('Imagenes/coches.png', conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/PIDDeteccionVehiculos/Entrega_Final/Imagenes/coches.png: 704x1280 20 Coches, 401.1ms
# Speed: 7.5ms preprocess, 401.1ms inference, 3.3ms postprocess per image at shape (1, 3, 704, 1280)
# ...
# <PIL.Image.Image image mode=RGB size=1287x705>

# %%
results = model('Imagenes/coches2.png', conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/PIDDeteccionVehiculos/Entrega_Final/Imagenes/coches2.png: 608x1280 20 Coches, 362.7ms
# Speed: 11.4ms preprocess, 362.7ms inference, 3.1ms postprocess per image at shape (1, 3, 608, 1280)
# <PIL.Image.Image image mode=RGB size=1537x717>

# %%
results = model('Imagenes/coches3.png', conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/PIDDeteccionVehiculos/Entrega_Final/Imagenes/coches3.png: 512x1280 69 Coches, 1 Camion, 309.2ms
# Speed: 5.9ms preprocess, 309.2ms inference, 9.4ms postprocess per image at shape (1, 3, 512, 1280)
# <PIL.Image.Image image mode=RGB size=1661x648>

# %%
results = model('Imagenes/coches4.png', conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/PIDDeteccionVehiculos/Entrega_Final/Imagenes/coches4.png: 736x1280 18 Coches, 1 Camioneta, 459.5ms
# Speed: 9.7ms preprocess, 459.5ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 1280)
# <PIL.Image.Image image mode=RGB size=1195x667>
